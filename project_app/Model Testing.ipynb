# %%
import pickle
import  json
import numpy as np
import pandas as pd

# %%
with open('logistic_reg_model.pkl','rb') as f:
    logistic_model = pickle.load(f)


logistic_model
# Out:
# LogisticRegression(multi_class='ovr')

# %%
column_names = logistic_model.feature_names_in_
column_names
# Out:
# array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
#       dtype=object)

# %%
len(column_names)
# Out:
# 4

# %%
fetaure_count = logistic_model.n_features_in_
fetaure_count
# Out:
# 4

# %% [markdown]
# # USER

# %%
SepalLengthCm = 3.2
SepalWidthCm = 3.4
PetalLengthCm = 4.0
PetalWidthCm = 2.1

# %%
column_names
# Out:
# array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
#       dtype=object)

# %%
test_array = np.zeros(fetaure_count)
test_array
# Out:
# array([0., 0., 0., 0.])

# %%
test_array[0] = SepalLengthCm
test_array[1] = SepalLengthCm
test_array[2] = PetalLengthCm
test_array[3] = PetalWidthCm

# %%
test_array
# Out:
# array([3.2, 3.2, 4. , 2.1])

# %%
flowerspieces = logistic_model.predict([test_array])[0]
print("Predicted Medical Insurance Charges is : ",flowerspieces )
# Out:
# Predicted Medical Insurance Charges is :  virginica
# C:\Users\GLOBAL\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
